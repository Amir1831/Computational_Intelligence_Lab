# %% [markdown]
# # Convolutional Neural Networks: Application

# %% [markdown]
# <a name='1'></a>
# ## 1 - Packages

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
from PIL import Image
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.python.framework import ops
from cnn_utils import *
from test_utils import summary, comparator

# %matplotlib inline
np.random.seed(1)

# %% [markdown]
# <a name='1-1'></a>
# ### 1.1 - Load the Data and Split the Data into Train/Test Sets

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_happy_dataset()

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %%
index = 11
plt.imshow(X_train_orig[index]) #display sample training image
plt.show()

# %% [markdown]
# <a name='2'></a>
# ## 2 - Layers in TF Keras

# %% [markdown]
# <a name='3'></a>
# ## 3 - The Sequential API

# %% [markdown]
# <a name='3-1'></a>
# ### 3.1 - Create the Sequential Model
#
# <a name='ex-1'></a>
# ### Exercise 1 - happyModel

# %%
# GRADED FUNCTION: happyModel

def happyModel():
    """
    Implements the forward propagation for the binary classification model:
    ZEROPAD2D -> CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code all the values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    None

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """
    model = tf.keras.Sequential([
            ## ZeroPadding2D with padding 3, input shape of 64 x 64 x 3
            tf.keras.layers.ZeroPadding2D(input_shape = (64,64,3),padding = (3,3)),
            ## Conv2D with 32 7x7 filters and stride of 1
            tf.keras.layers.Conv2D(32,7,1,input_shape=(70,70,3)),
            ## BatchNormalization for axis 3
            tf.keras.layers.BatchNormalization(axis=3,input_shape=(64,64,32)),
            ## ReLU
            tf.keras.layers.ReLU(),
            ## Max Pooling 2D with default parameters
            tf.keras.layers.MaxPool2D(input_shape=(32,32,32)),
            ## Flatten layer
            tf.keras.layers.Flatten(),
            ## Dense layer with 1 unit for output & 'sigmoid' activation
            tf.keras.layers.Dense(1,activation="sigmoid")
            # YOUR CODE STARTS HERE
            
            
            # YOUR CODE ENDS HERE
        ])
    
    return model

# %%
happy_model = happyModel()
# Print a summary for each layer
for layer in summary(happy_model):
    print(layer)
    
output = [['ZeroPadding2D', (None, 70, 70, 3), 0, ((3, 3), (3, 3))],
            ['Conv2D', (None, 64, 64, 32), 4736, 'valid', 'linear', 'GlorotUniform'],
            ['BatchNormalization', (None, 64, 64, 32), 128],
            ['ReLU', (None, 64, 64, 32), 0],
            ['MaxPooling2D', (None, 32, 32, 32), 0, (2, 2), (2, 2), 'valid'],
            ['Flatten', (None, 32768), 0],
            ['Dense', (None, 1), 32769, 'sigmoid']]
    
comparator(summary(happy_model), output)
# Out:
# ['ZeroPadding2D', (None, 70, 70, 3), 0, ((3, 3), (3, 3))]
# ['Conv2D', (None, 64, 64, 32), 4736, 'valid', 'linear', 'GlorotUniform']
# ['BatchNormalization', (None, 64, 64, 32), 128]
# ['ReLU', (None, 64, 64, 32), 0]
# ['MaxPooling2D', (None, 32, 32, 32), 0, (2, 2), (2, 2), 'valid']
# ['Flatten', (None, 32768), 0]
# ['Dense', (None, 1), 32769, 'sigmoid']
# All tests passed!

# %%
happy_model.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

# %%
happy_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  zero_padding2d_13 (ZeroPadd  (None, 70, 70, 3)        0
#  ing2D)
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 32)        4736
#
#  batch_normalization_13 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 64, 64, 32)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  flatten_7 (Flatten)         (None, 32768)             0
#
#  dense_5 (Dense)             (None, 1)                 32769
#
# =================================================================
# Total params: 37,633
# Trainable params: 37,569
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# <a name='3-2'></a>
# ### 3.2 - Train and Evaluate the Model

# %%
happy_model.fit(X_train, Y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 19/19 [==============================] - 1s 4ms/step - loss: 1.7011 - accuracy: 0.6367
# Epoch 2/10
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2601 - accuracy: 0.9017
# Epoch 3/10
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1677 - accuracy: 0.9300
# Epoch 4/10
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1312 - accuracy: 0.9567
# Epoch 5/10
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1117 - accuracy: 0.9567
# Epoch 6/10
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0844 - accuracy: 0.9817
# Epoch 7/10
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0975 - accuracy: 0.9700
# Epoch 8/10
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0767 - accuracy: 0.9833
# Epoch 9/10
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0716 - accuracy: 0.9800
# Epoch 10/10
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1522 - accuracy: 0.9383

# %%
happy_model.evaluate(X_test, Y_test)
# Out:
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3007 - accuracy: 0.8800
# [0.3006942868232727, 0.8799999952316284]

# %% [markdown]
# <a name='4'></a>
# ## 4 - The Functional API

# %% [markdown]
# <a name='4-1'></a>
# ### 4.1 - Load the SIGNS Dataset

# %%
# Loading the data (signs)
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_signs_dataset()

# %%
# Example of an image from the dataset
index = 13
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 5

# %% [markdown]
# <a name='4-2'></a>
# ### 4.2 - Split the Data into Train/Test Sets

# %%
X_train = X_train_orig/255.
X_test = X_test_orig/255.
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T
# print(type(X_train))
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %% [markdown]
# <a name='4-3'></a>
# ### 4.3 - Forward Propagation

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - convolutional_model

# %%
# GRADED FUNCTION: convolutional_model

def convolutional_model(input_shape):
    """
    Implements the forward propagation for the model:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code some values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    input_img -- input dataset, of shape (input_shape)

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """

    input_img = tf.keras.Input(shape=input_shape)
    ## CONV2D: 8 filters 4x4, stride of 1, padding 'SAME'
    x = tf.keras.layers.Conv2D(8,4,1,padding="same",activation="relu")(input_img)
    # Z1 = None
    ## RELU
    
    ## MAXPOOL: window 8x8, stride 8, padding 'SAME'
    x = tf.keras.layers.MaxPool2D(8,8,padding='same')(x)
    ## CONV2D: 16 filters 2x2, stride 1, padding 'SAME'
    x = tf.keras.layers.Conv2D(16,2,1,padding='same',activation='relu')(x)
    ## RELU
    
    ## MAXPOOL: window 4x4, stride 4, padding 'SAME'
    x = tf.keras.layers.MaxPool2D(4,4,padding='same')(x)
    ## FLATTEN
    x = tf.keras.layers.Flatten()(x)
    ## Dense layer
    ## 6 neurons in output layer. Hint: one of the arguments should be "activation='softmax'" 
    outputs = tf.keras.layers.Dense(6,activation="softmax")(x)
    # YOUR CODE STARTS HERE
    
    
    # YOUR CODE ENDS HERE
    model = tf.keras.Model(inputs=input_img, outputs=outputs)
    return model

# %%
conv_model = convolutional_model((64, 64, 3))
conv_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
conv_model.summary()
    
output = [['InputLayer', [(None, 64, 64, 3)], 0],
        ['Conv2D', (None, 64, 64, 8), 392, 'same', 'linear', 'GlorotUniform'],
        ['ReLU', (None, 64, 64, 8), 0],
        ['MaxPooling2D', (None, 8, 8, 8), 0, (8, 8), (8, 8), 'same'],
        ['Conv2D', (None, 8, 8, 16), 528, 'same', 'linear', 'GlorotUniform'],
        ['ReLU', (None, 8, 8, 16), 0],
        ['MaxPooling2D', (None, 2, 2, 16), 0, (4, 4), (4, 4), 'same'],
        ['Flatten', (None, 64), 0],
        ['Dense', (None, 6), 390, 'softmax']]
    
comparator(summary(conv_model), output)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d_16 (Conv2D)          (None, 64, 64, 8)         392
#
#  max_pooling2d_12 (MaxPoolin  (None, 8, 8, 8)          0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 16)          528
#
#  max_pooling2d_13 (MaxPoolin  (None, 2, 2, 16)         0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 1,310
# Trainable params: 1,310
# Non-trainable params: 0
# _________________________________________________________________
# Test failed
#  Expected value
#
#  ['Conv2D', (None, 64, 64, 8), 392, 'same', 'linear', 'GlorotUniform']
#
#  does not match the input value:
#
#  ['Conv2D', (None, 64, 64, 8), 392, 'same', 'relu', 'GlorotUniform']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [45], line 17
#       5 conv_model.summary()
#       7 output = [['InputLayer', [(None, 64, 64, 3)], 0],
#       8         ['Conv2D', (None, 64, 64, 8), 392, 'same', 'linear', 'GlorotUniform'],
#       9         ['ReLU', (None, 64, 64, 8), 0],
#    (...)
#      14         ['Flatten', (None, 64), 0],
#      15         ['Dense', (None, 6), 390, 'softmax']]
# ---> 17 comparator(summary(conv_model), output)
#
# File ~/Storage/Session_6/test_utils.py:22, in comparator(learner, instructor)
#      17     if tuple(a) != tuple(b):
#      18         print(colored("Test failed", attrs=['bold']),
#      19               "\n Expected value \n\n", colored(f"{b}", "green"),
#      20               "\n\n does not match the input value: \n\n",
#      21               colored(f"{a}", "red"))
# ---> 22         raise AssertionError("Error in test")
#      23 print(colored("All tests passed!", "green"))
#
# AssertionError: Error in test

# %% [markdown]
# <a name='4-4'></a>
# ### 4.4 - Train the Model

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(64)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test)).batch(64)
history = conv_model.fit(train_dataset, epochs=100, validation_data=test_dataset)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 0s 11ms/step - loss: 1.7959 - accuracy: 0.1454 - val_loss: 1.7923 - val_accuracy: 0.1583
# Epoch 2/100
# 17/17 [==============================] - 0s 4ms/step - loss: 1.7906 - accuracy: 0.1824 - val_loss: 1.7908 - val_accuracy: 0.1500
# Epoch 3/100
# 17/17 [==============================] - 0s 4ms/step - loss: 1.7879 - accuracy: 0.1963 - val_loss: 1.7883 - val_accuracy: 0.1917
# Epoch 4/100
# 17/17 [==============================] - 0s 4ms/step - loss: 1.7854 - accuracy: 0.2065 - val_loss: 1.7855 - val_accuracy: 0.2250
# Epoch 5/100
# 17/17 [==============================] - 0s 5ms/step - loss: 1.7823 - accuracy: 0.2185 - val_loss: 1.7832 - val_accuracy: 0.2833
# Epoch 6/100
# 17/17 [==============================] - 0s 6ms/step - loss: 1.7796 - accuracy: 0.2278 - val_loss: 1.7799 - val_accuracy: 0.2667
# Epoch 7/100
# 17/17 [==============================] - 0s 6ms/step - loss: 1.7754 - accuracy: 0.2528 - val_loss: 1.7754 - val_accuracy: 0.3000
# Epoch 8/100
# 17/17 [==============================] - 0s 6ms/step - loss: 1.7701 - accuracy: 0.3167 - val_loss: 1.7710 - val_accuracy: 0.3500
# Epoch 9/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.7651 - accuracy: 0.2861 - val_loss: 1.7654 - val_accuracy: 0.2583
# Epoch 10/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.7586 - accuracy: 0.2556 - val_loss: 1.7578 - val_accuracy: 0.3750
# Epoch 11/100
# 17/17 [==============================] - 0s 12ms/step - loss: 1.7503 - accuracy: 0.3065 - val_loss: 1.7488 - val_accuracy: 0.3833
# Epoch 12/100
# 17/17 [==============================] - 0s 12ms/step - loss: 1.7399 - accuracy: 0.3250 - val_loss: 1.7375 - val_accuracy: 0.3750
# Epoch 13/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.7272 - accuracy: 0.3343 - val_loss: 1.7247 - val_accuracy: 0.3667
# Epoch 14/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.7108 - accuracy: 0.3565 - val_loss: 1.7138 - val_accuracy: 0.2833
# Epoch 15/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.6882 - accuracy: 0.3509 - val_loss: 1.6978 - val_accuracy: 0.2750
# Epoch 16/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.6585 - accuracy: 0.3880 - val_loss: 1.6697 - val_accuracy: 0.3083
# Epoch 17/100
# 17/17 [==============================] - 0s 12ms/step - loss: 1.6231 - accuracy: 0.4065 - val_loss: 1.6241 - val_accuracy: 0.3667
# Epoch 18/100
# 17/17 [==============================] - 0s 12ms/step - loss: 1.5886 - accuracy: 0.4231 - val_loss: 1.5876 - val_accuracy: 0.3750
# Epoch 19/100
# 17/17 [==============================] - 0s 12ms/step - loss: 1.5519 - accuracy: 0.4500 - val_loss: 1.5513 - val_accuracy: 0.3833
# Epoch 20/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.5092 - accuracy: 0.4648 - val_loss: 1.5123 - val_accuracy: 0.4250
# Epoch 21/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.4684 - accuracy: 0.4769 - val_loss: 1.4706 - val_accuracy: 0.4500
# Epoch 22/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.4222 - accuracy: 0.4889 - val_loss: 1.4280 - val_accuracy: 0.4750
# Epoch 23/100
# 17/17 [==============================] - 0s 12ms/step - loss: 1.3776 - accuracy: 0.4981 - val_loss: 1.3832 - val_accuracy: 0.4750
# Epoch 24/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.3370 - accuracy: 0.5176 - val_loss: 1.3434 - val_accuracy: 0.5000
# Epoch 25/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.2973 - accuracy: 0.5278 - val_loss: 1.3088 - val_accuracy: 0.5250
# Epoch 26/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.2563 - accuracy: 0.5491 - val_loss: 1.2715 - val_accuracy: 0.5583
# Epoch 27/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.2162 - accuracy: 0.5648 - val_loss: 1.2364 - val_accuracy: 0.5667
# Epoch 28/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.1795 - accuracy: 0.5824 - val_loss: 1.2039 - val_accuracy: 0.5667
# Epoch 29/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.1440 - accuracy: 0.5917 - val_loss: 1.1721 - val_accuracy: 0.5833
# Epoch 30/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.1110 - accuracy: 0.6000 - val_loss: 1.1446 - val_accuracy: 0.5833
# Epoch 31/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.0772 - accuracy: 0.6167 - val_loss: 1.1114 - val_accuracy: 0.6083
# Epoch 32/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.0455 - accuracy: 0.6343 - val_loss: 1.0825 - val_accuracy: 0.6167
# Epoch 33/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.0166 - accuracy: 0.6537 - val_loss: 1.0574 - val_accuracy: 0.6167
# Epoch 34/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.9902 - accuracy: 0.6620 - val_loss: 1.0362 - val_accuracy: 0.6250
# Epoch 35/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.9641 - accuracy: 0.6704 - val_loss: 1.0155 - val_accuracy: 0.6417
# Epoch 36/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.9396 - accuracy: 0.6843 - val_loss: 0.9993 - val_accuracy: 0.6250
# Epoch 37/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.9167 - accuracy: 0.6954 - val_loss: 0.9790 - val_accuracy: 0.6583
# Epoch 38/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.8953 - accuracy: 0.7074 - val_loss: 0.9618 - val_accuracy: 0.6583
# Epoch 39/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.8741 - accuracy: 0.7213 - val_loss: 0.9444 - val_accuracy: 0.6583
# Epoch 40/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.8552 - accuracy: 0.7315 - val_loss: 0.9298 - val_accuracy: 0.6583
# Epoch 41/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.8365 - accuracy: 0.7398 - val_loss: 0.9142 - val_accuracy: 0.6667
# Epoch 42/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.8202 - accuracy: 0.7435 - val_loss: 0.9024 - val_accuracy: 0.6750
# Epoch 43/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.8030 - accuracy: 0.7463 - val_loss: 0.8873 - val_accuracy: 0.6917
# Epoch 44/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.7874 - accuracy: 0.7556 - val_loss: 0.8772 - val_accuracy: 0.7000
# Epoch 45/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.7719 - accuracy: 0.7574 - val_loss: 0.8634 - val_accuracy: 0.7000
# Epoch 46/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.7574 - accuracy: 0.7630 - val_loss: 0.8533 - val_accuracy: 0.7000
# Epoch 47/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.7436 - accuracy: 0.7648 - val_loss: 0.8403 - val_accuracy: 0.7167
# Epoch 48/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.7308 - accuracy: 0.7713 - val_loss: 0.8300 - val_accuracy: 0.7250
# Epoch 49/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.7190 - accuracy: 0.7759 - val_loss: 0.8196 - val_accuracy: 0.7250
# Epoch 50/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.7072 - accuracy: 0.7787 - val_loss: 0.8093 - val_accuracy: 0.7250
# Epoch 51/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.6958 - accuracy: 0.7833 - val_loss: 0.7998 - val_accuracy: 0.7333
# Epoch 52/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.6844 - accuracy: 0.7833 - val_loss: 0.7903 - val_accuracy: 0.7333
# Epoch 53/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.6739 - accuracy: 0.7889 - val_loss: 0.7817 - val_accuracy: 0.7417
# Epoch 54/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.6636 - accuracy: 0.7926 - val_loss: 0.7735 - val_accuracy: 0.7417
# Epoch 55/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.6536 - accuracy: 0.7963 - val_loss: 0.7649 - val_accuracy: 0.7417
# Epoch 56/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.6436 - accuracy: 0.7972 - val_loss: 0.7571 - val_accuracy: 0.7417
# Epoch 57/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.6339 - accuracy: 0.8009 - val_loss: 0.7479 - val_accuracy: 0.7417
# Epoch 58/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.6242 - accuracy: 0.8065 - val_loss: 0.7399 - val_accuracy: 0.7500
# Epoch 59/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.6151 - accuracy: 0.8065 - val_loss: 0.7325 - val_accuracy: 0.7500
# Epoch 60/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.6067 - accuracy: 0.8056 - val_loss: 0.7247 - val_accuracy: 0.7417
# Epoch 61/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.5986 - accuracy: 0.8130 - val_loss: 0.7178 - val_accuracy: 0.7500
# Epoch 62/100
# 17/17 [==============================] - 0s 12ms/step - loss: 0.5906 - accuracy: 0.8167 - val_loss: 0.7103 - val_accuracy: 0.7583
# Epoch 63/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.5829 - accuracy: 0.8185 - val_loss: 0.7055 - val_accuracy: 0.7667
# Epoch 64/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.5749 - accuracy: 0.8222 - val_loss: 0.6975 - val_accuracy: 0.7667
# Epoch 65/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5675 - accuracy: 0.8250 - val_loss: 0.6906 - val_accuracy: 0.7667
# Epoch 66/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5603 - accuracy: 0.8269 - val_loss: 0.6850 - val_accuracy: 0.7750
# Epoch 67/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.5534 - accuracy: 0.8287 - val_loss: 0.6790 - val_accuracy: 0.7750
# Epoch 68/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.5468 - accuracy: 0.8324 - val_loss: 0.6728 - val_accuracy: 0.7917
# Epoch 69/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5405 - accuracy: 0.8370 - val_loss: 0.6670 - val_accuracy: 0.7917
# Epoch 70/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5345 - accuracy: 0.8389 - val_loss: 0.6615 - val_accuracy: 0.7917
# Epoch 71/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5287 - accuracy: 0.8398 - val_loss: 0.6559 - val_accuracy: 0.7917
# Epoch 72/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5230 - accuracy: 0.8435 - val_loss: 0.6508 - val_accuracy: 0.7917
# Epoch 73/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5174 - accuracy: 0.8472 - val_loss: 0.6456 - val_accuracy: 0.7917
# Epoch 74/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5120 - accuracy: 0.8481 - val_loss: 0.6412 - val_accuracy: 0.7917
# Epoch 75/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5063 - accuracy: 0.8472 - val_loss: 0.6365 - val_accuracy: 0.7917
# Epoch 76/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5005 - accuracy: 0.8509 - val_loss: 0.6313 - val_accuracy: 0.7917
# Epoch 77/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4953 - accuracy: 0.8519 - val_loss: 0.6268 - val_accuracy: 0.8000
# Epoch 78/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4906 - accuracy: 0.8537 - val_loss: 0.6220 - val_accuracy: 0.8000
# Epoch 79/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4855 - accuracy: 0.8537 - val_loss: 0.6176 - val_accuracy: 0.8000
# Epoch 80/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4805 - accuracy: 0.8556 - val_loss: 0.6127 - val_accuracy: 0.7917
# Epoch 81/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4759 - accuracy: 0.8565 - val_loss: 0.6090 - val_accuracy: 0.7917
# Epoch 82/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4715 - accuracy: 0.8583 - val_loss: 0.6048 - val_accuracy: 0.7917
# Epoch 83/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4669 - accuracy: 0.8602 - val_loss: 0.6005 - val_accuracy: 0.7917
# Epoch 84/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4626 - accuracy: 0.8611 - val_loss: 0.5969 - val_accuracy: 0.7917
# Epoch 85/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4585 - accuracy: 0.8620 - val_loss: 0.5930 - val_accuracy: 0.7917
# Epoch 86/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4542 - accuracy: 0.8630 - val_loss: 0.5898 - val_accuracy: 0.7917
# Epoch 87/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4500 - accuracy: 0.8630 - val_loss: 0.5850 - val_accuracy: 0.7917
# Epoch 88/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4460 - accuracy: 0.8657 - val_loss: 0.5827 - val_accuracy: 0.7917
# Epoch 89/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4421 - accuracy: 0.8667 - val_loss: 0.5779 - val_accuracy: 0.7917
# Epoch 90/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4383 - accuracy: 0.8667 - val_loss: 0.5749 - val_accuracy: 0.7917
# Epoch 91/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4345 - accuracy: 0.8685 - val_loss: 0.5714 - val_accuracy: 0.8000
# Epoch 92/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4307 - accuracy: 0.8704 - val_loss: 0.5681 - val_accuracy: 0.8000
# Epoch 93/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4271 - accuracy: 0.8713 - val_loss: 0.5649 - val_accuracy: 0.8000
# Epoch 94/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4236 - accuracy: 0.8713 - val_loss: 0.5618 - val_accuracy: 0.8000
# Epoch 95/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4199 - accuracy: 0.8704 - val_loss: 0.5582 - val_accuracy: 0.8000
# Epoch 96/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4162 - accuracy: 0.8722 - val_loss: 0.5558 - val_accuracy: 0.8000
# Epoch 97/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4127 - accuracy: 0.8741 - val_loss: 0.5521 - val_accuracy: 0.8083
# Epoch 98/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4091 - accuracy: 0.8769 - val_loss: 0.5495 - val_accuracy: 0.8000
# Epoch 99/100
# 17/17 [==============================] - 0s 11ms/step - loss: 0.4058 - accuracy: 0.8769 - val_loss: 0.5462 - val_accuracy: 0.8083
# Epoch 100/100
# 17/17 [==============================] - 0s 11ms/step - loss: 0.4025 - accuracy: 0.8778 - val_loss: 0.5437 - val_accuracy: 0.8083

# %% [markdown]
# <a name='5'></a>
# ## 5 - History Object

# %%
history.history
# Out:
# {'loss': [1.795949935913086,
#   1.7905967235565186,
#   1.787901520729065,
#   1.7854145765304565,
#   1.7823220491409302,
#   1.7796146869659424,
#   1.7754496335983276,
#   1.7700555324554443,
#   1.7651081085205078,
#   1.7585859298706055,
#   1.7502670288085938,
#   1.739854097366333,
#   1.7271517515182495,
#   1.7107868194580078,
#   1.688185453414917,
#   1.6585345268249512,
#   1.6231168508529663,
#   1.588579773902893,
#   1.5518683195114136,
#   1.5091876983642578,
#   1.4683868885040283,
#   1.4221758842468262,
#   1.3775839805603027,
#   1.3369581699371338,
#   1.2973297834396362,
#   1.256250023841858,
#   1.2162437438964844,
#   1.1795413494110107,
#   1.1439958810806274,
#   1.1110376119613647,
#   1.0772005319595337,
#   1.0454983711242676,
#   1.016635537147522,
#   0.9901639819145203,
#   0.964116096496582,
#   0.9396265149116516,
#   0.9167460203170776,
#   0.8953356742858887,
#   0.8740702867507935,
#   0.8551733493804932,
#   0.8365402221679688,
#   0.8201909065246582,
#   0.8030168414115906,
#   0.7873637080192566,
#   0.7719281911849976,
#   0.7573874592781067,
#   0.7436443567276001,
#   0.7307962775230408,
#   0.7189688682556152,
#   0.7071999311447144,
#   0.6957693099975586,
#   0.6844143271446228,
#   0.6739246249198914,
#   0.6636201739311218,
#   0.6536200046539307,
#   0.6435797810554504,
#   0.6338548064231873,
#   0.6242223381996155,
#   0.6150653958320618,
#   0.6067476868629456,
#   0.5985508561134338,
#   0.5905762910842896,
#   0.5828579664230347,
#   0.5748653411865234,
#   0.5675268173217773,
#   0.5602535009384155,
#   0.5534293055534363,
